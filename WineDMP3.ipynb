# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.pyplot as mplt
from pandas.tools.plotting import scatter_matrix
# %matplotlib inline

# %%
df = pd.read_csv('wine.csv')
df.head(100)
# Out:
#     Unnamed: 0    country                                        description  \
# 0            0      Italy  Aromas include tropical fruit, broom, brimston...
# 1            1   Portugal  This is ripe and fruity, a wine that is smooth...
# 2            2         US  Tart and snappy, the flavors of lime flesh and...
# 3            3         US  Pineapple rind, lemon pith and orange blossom ...
# 4            4         US  Much like the regular bottling from 2012, this...
# 5            5      Spain  Blackberry and raspberry aromas show a typical...
# 6            6      Italy  Here's a bright, informal red that opens with ...
# 7            7     France  This dry and restrained wine offers spice in p...
# 8            8    Germany  Savory dried thyme notes accent sunnier flavor...
# 9            9     France  This has great depth of flavor with its fresh ...
# 10          10         US  Soft, supple plum envelopes an oaky structure ...
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'country', 'description', 'designation', 'points',
#        'price', 'province', 'region_1', 'region_2', 'taster_name',
#        'taster_twitter_handle', 'title', 'variety', 'winery'],
#       dtype='object')

# %%
df.columns=[ 'index',  u'country', u'description', u'designation', u'points',
       u'price', u'province', u'region_1', u'region_2', u'taster_name', u'taster_twitter_handle', u'title', u'variety', u'winery' ]

# %%
df.set_index('index', inplace=True)

# %%
df.head(5)
# Out:
#         country                                        description  \
# index
# 0         Italy  Aromas include tropical fruit, broom, brimston...
# 1      Portugal  This is ripe and fruity, a wine that is smooth...
# 2            US  Tart and snappy, the flavors of lime flesh and...
# 3            US  Pineapple rind, lemon pith and orange blossom ...
# 4            US  Much like the regular bottling from 2012, this...
#
#                               designation  points  price           province  \
# index
# 0                            Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                                Avidagos      87   15.0              Douro
# 2                                     NaN      87   14.0             Oregon
# 3                    Reserve Late Harvest      87   13.0           Michigan
# 4      Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#                   region_1           region_2         taster_name  \
# index
# ...

# %%
sns.heatmap(df.corr())

# %%
data = pd.read_csv('wine.csv')
scatter_matrix(data)
mplt.show()
# Out:
# C:\Users\denni\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.

# %%
np.mean(df['price'])
# Out:
# 35.363389129985535

# %%
np.mean(df['points'])
# Out:
# 88.44713820775404

# %%
import statistics
statistics.mode(df['price'])
# Out:
# 20.0

# %%
statistics.mode(df['points'])
# Out:
# 88

# %%
statistics.mode(df['country'])
# Out:
# 'US'

# %%
 df['price'].var
# Out:
# <bound method Series.var of index
# 0          NaN
# 1         15.0
# 2         14.0
# 3         13.0
# 4         65.0
# 5         15.0
# 6         16.0
# 7         24.0
# 8         12.0
# 9         27.0
# 10        19.0
# 11        30.0
# 12        34.0
# 13         NaN
# 14        12.0
# 15        24.0
# 16        30.0
# 17        13.0
# 18        28.0
# 19        32.0
# 20        23.0
# 21        20.0
# 22        19.0
# 23        22.0
# 24        35.0
# 25        69.0
# 26        13.0
# 27        10.0
# 28        17.0
# 29        16.0
#           ...
# 129941    20.0
# 129942    35.0
# 129943    29.0
# 129944    25.0
# 129945    20.0
# 129946    17.0
# 129947    20.0
# 129948    43.0
# 129949    35.0
# 129950    35.0
# 129951    30.0
# 129952    22.0
# 129953    25.0
# 129954    15.0
# 129955    40.0
# 129956    19.0
# 129957    17.0
# 129958    35.0
# 129959    57.0
# 129960    48.0
# 129961    30.0
# 129962    40.0
# 129963    20.0
# 129964     NaN
# 129965    28.0
# ...

# %%
 df['points'].var
# Out:
# <bound method Series.var of index
# 0         87
# 1         87
# 2         87
# 3         87
# 4         87
# 5         87
# 6         87
# 7         87
# 8         87
# 9         87
# 10        87
# 11        87
# 12        87
# 13        87
# 14        87
# 15        87
# 16        87
# 17        87
# 18        87
# 19        87
# 20        87
# 21        87
# 22        87
# 23        87
# 24        87
# 25        87
# 26        87
# 27        87
# 28        87
# 29        86
#           ..
# 129941    90
# 129942    90
# 129943    90
# 129944    90
# 129945    90
# 129946    90
# 129947    90
# 129948    90
# 129949    90
# 129950    90
# 129951    90
# 129952    90
# 129953    90
# 129954    90
# 129955    90
# 129956    90
# 129957    90
# 129958    90
# 129959    90
# 129960    90
# 129961    90
# 129962    90
# 129963    90
# 129964    90
# 129965    90
# 129966    90
# 129967    90
# 129968    90
# 129969    90
# 129970    90
# Name: points, Length: 129971, dtype: int64>

# %%
np.std(df['price'], ddof=1)
# Out:
# 41.02221766808889

# %%
np.std(df['points'], ddof=1)
# Out:
# 3.0397302029162336

# %%
def surveyData(self, data_url, columns)
"""
Params: data_url - location of data file
        columns  - list of names for column headers
Return: Plot a Scatter Plot
"""#Access data, apply titles
    data = pd.read_csv(data_url, names=columns)
    #Scatter matrix
    scatter_matrix(data)
    mplt.show()

if __name__ == '__main__':
    #set target
    data_url = "https://archive.ics.uci.edu/ml/
               machine-learning-databases/abalone/abalone.data"#set titles                                                          
    columns = ['Sex','Length','Diameter','Height','WholeWeight', 
               'ShuckedWeight', 'VisceraWeight', 'ShellWeight', 'Rings']

# %%
    df2 = df.columns = ['Unnamed: 0', 'country', 'description', 'designation', 'points', 'price', 'province', 'region_1', 'region_2', 'taster_name', 'taster_twitter_handle', 'title', 'variety', 'winery']
    list_index= np.linspace(0, 129970) 
    df2 = df.index = [list_index]
    print(df2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-03305e058e30> in <module>()
#       1 df2 = df.columns = ['Unnamed: 0', 'country', 'description', 'designation', 'points', 'price', 'province', 'region_1', 'region_2', 'taster_name', 'taster_twitter_handle', 'title', 'variety', 'winery']
#       2 list_index= np.linspace(0, 129970)
# ----> 3 df2 = df.index = [list_index]
#       4 print(df2)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    4383         try:
#    4384             object.__getattribute__(self, name)
# -> 4385             return object.__setattr__(self, name, value)
#    4386         except AttributeError:
#    4387             pass
#
# pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
# ...
